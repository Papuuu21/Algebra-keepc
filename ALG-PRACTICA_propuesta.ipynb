# %% [markdown]
# <img src="images/keepcoding.png" width=200 align="left">

# %% [markdown]
# # Módulo de Matemáticas 101: práctica
#
# Vamos a poner de nuevo en práctica lo que hemos visto en este módulo. La práctica se centra en la regresión lineal (¡tema muy importante!) y podéis preguntarme las dudas que tengáis por Discord. ¡Mucha suerte!
#
# <img src="./images/luck.gif" alt="Drawing" style="width: 300px;"/>

# %% [markdown]
# ## 1. Regresión lineal con mínimos cuadrados
#
# En este ejercicio vamos a implementar la forma matricial de la regresión lineal con el método de los mínimos cuadrados. Para ello, tendrás que:
#
# - Explorar un dataset
# - Implementar la regresión lineal
# - Aplicarla a los datos
#
# Como recordatorio, los valores de los pesos $\widehat{w}$ vienen dados por:
#
# <center>$\widehat{w} = (X^T X)^{-1}X^T y,$</center>
#
# Donde $y$ es la variable a predecir y $X$ la matriz de features (NOTA: revisa cómo se define en los apuntes). Sabemos que los pesos van a ser los parámetros de la ecuación lineal que estamos intentando ajustar y tendremos uno por cada variable de entrada que usemos y además un término independiente o bias.

# %% [markdown]
# ### 1.1 Carga del dataset y exploración de datos
#
# Vamos a usar el dataset de [Auto MPG](https://archive.ics.uci.edu/dataset/9/auto+mpg) que podemos encontrar en el [repositorio de Machine learning de UC Irvine](https://archive.ics.uci.edu/). Lo primero, vamos a familiarizarnos con los datos.
#
# En el propio repositorio nos indican cómo descargar el dataset con su librería (podemos consultar el código fuente si queremos).

# %%
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in c:\users\papui\anaconda3\lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\papui\anaconda3\lib\site-packages (from ucimlrepo) (2.1.4)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\papui\anaconda3\lib\site-packages (from ucimlrepo) (2024.2.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\papui\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\papui\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\papui\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\papui\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\papui\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
auto_mpg = fetch_ucirepo(id=9) 
  
# data (as pandas dataframes) 
X = auto_mpg.data.features 
y = auto_mpg.data.targets 
  
# metadata 
print(auto_mpg.metadata) 
  
# variable information 
print(auto_mpg.variables)
# Out:
# {'uci_id': 9, 'name': 'Auto MPG', 'repository_url': 'https://archive.ics.uci.edu/dataset/9/auto+mpg', 'data_url': 'https://archive.ics.uci.edu/static/public/9/data.csv', 'abstract': 'Revised from CMU StatLib library, data concerns city-cycle fuel consumption', 'area': 'Other', 'tasks': ['Regression'], 'characteristics': ['Multivariate'], 'num_instances': 398, 'num_features': 7, 'feature_types': ['Real', 'Categorical', 'Integer'], 'demographics': [], 'target_col': ['mpg'], 'index_col': ['car_name'], 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1993, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5859H', 'creators': ['R. Quinlan'], 'intro_paper': None, 'additional_info': {'summary': 'This dataset is a slightly modified version of the dataset provided in the StatLib library.  In line with the use by Ross Quinlan (1993) in predicting the attribute "mpg", 8 of the original instances were removed because they had unknown values for the "mpg" attribute.  The original dataset is available in the file "auto-mpg.data-original".\r\n\r\n"The data concerns city-cycle fuel consumption in miles per gallon, to be predicted in terms of 3 multivalued discrete and 5 continuous attributes." (Quinlan, 1993)', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '    1. mpg:           continuous\r\n    2. cylinders:     multi-valued discrete\r\n    3. displacement:  continuous\r\n    4. horsepower:    continuous\r\n    5. weight:        continuous\r\n    6. acceleration:  continuous\r\n    7. model year:    multi-valued discrete\r\n    8. origin:        multi-valued discrete\r\n    9. car name:      string (unique for each instance)', 'citation': None}}
#            name     role         type demographic description units  \
# 0  displacement  Feature   Continuous        None        None  None
# 1           mpg   Target   Continuous        None        None  None
# 2     cylinders  Feature      Integer        None        None  None
# 3    horsepower  Feature   Continuous        None        None  None
# 4        weight  Feature   Continuous        None        None  None
# 5  acceleration  Feature   Continuous        None        None  None
# 6    model_year  Feature      Integer        None        None  None
# 7        origin  Feature      Integer        None        None  None
# 8      car_name       ID  Categorical        None        None  None
#
#   missing_values
# 0             no
# 1             no
# 2             no
# 3            yes
# 4             no
# 5             no
# 6             no
# 7             no
# 8             no

# %% [markdown]
# Con la función `head` de Pandas podemos ver las primeras filas del dataset.

# %%
X.head()
# Out:
#    displacement  cylinders  horsepower  weight  acceleration  model_year  \
# 0         307.0          8       130.0    3504          12.0          70
# 1         350.0          8       165.0    3693          11.5          70
# 2         318.0          8       150.0    3436          11.0          70
# 3         304.0          8       150.0    3433          12.0          70
# 4         302.0          8       140.0    3449          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
y.head()
# Out:
#     mpg
# 0  18.0
# 1  15.0
# 2  18.0
# 3  16.0
# 4  17.0

# %%
print(X.shape)
print(y.shape)
# Out:
# (398, 7)
# (398, 1)

# %% [markdown]
# Crea una función a la que le pases los dataframes de features y de target y el nombre de la variable y haga la gráfica del target (consumo en galones por milla) vs la variable que le ha llegado por parámetro. Puedes ver un ejemplo de gráfica más abajo.

# %%
import matplotlib.pyplot as plt

X = auto_mpg.data.features 
y = auto_mpg.data.targets

def visualiza(df, y, nombre_columna):
    # TODO dibuja la gráfica
    df = X[nombre_columna]
    plt.scatter(df, y)
    plt.xlabel(f'{nombre_columna}')
    plt.ylabel('MPG')
    
visualiza(X, y, 'horsepower')

# %%
visualiza(X, y, 'acceleration')

# %%
visualiza(X, y, 'weight')

# %% [markdown]
# Aunque lo ideal sería un modelo multivariante, vamos a elegir la variable `weight` y hacer una regresión lineal solo con esta variable.

# %% [markdown]
# ### 1.2 Implementación del modelo
#
# Lo primero, implementa una función que devuelva los valores de $\widehat{w}$ dados X e y. Si se da el caso de que el dataset tiene más features que observaciones, queremos transponerlo antes de realizar las operaciones. Lo hacemos porque, como vimos en clase, los resultados no van a ser buenos si el número de observaciones es menor.

# %% [markdown]
# $W'=(X^{T}X)^{-1}X^{T}y$

# %%
import numpy as np

def pesos_ols(X, y):
    # Implementa la fórmula matricial
    #matricial = np.linalg.inv(np.dot(X_bt, X_b)).dot(X_bt).dot(y)
   
    # TODO 1 Comprueba que las dimensiones son adecuadas y corrige si no es así
    X_weight = X['weight'].values.reshape(-1, 1)

    print(X_weight.shape)
    print(y.shape)

    ones = np.ones((398, 1))
    X_weight_b = np.concatenate((ones, X_weight), axis = 1)
    print(X_weight_b.shape)

    # TODO 2 Prepara la matriz X para que tenga la forma adecuada para aplicar la fórmula 
    X_weight_bt = X_weight_b.T
    print(X_weight_bt.shape)

    # TODO 3 Calcula los pesos
    w = np.linalg.inv(np.dot(X_weight_bt, X_weight_b)).dot(X_weight_bt).dot(y)
    
    return w

# %%
X = auto_mpg.data.features 
y = auto_mpg.data.targets

pesos_ols(X, y)
# Out:
# (398, 1)
# (398, 1)
# (398, 2)
# (2, 398)
# array([[ 4.63173644e+01],
#        [-7.67661006e-03]])

# %% [markdown]
# $y = 46.31736 + -0.00768 x$

# %%
#X = np.array([[1710, 1262, 1786, 1717, 2198, 1362, 1694, 2090, 1774, 1077], 
             # [2003, 1976, 2001, 1915, 2000, 1993, 2004, 1973, 1931, 1939]])
#y = np.array([208500, 181500, 223500, 140000, 250000, 143000, 307000, 200000, 129900, 118000])

# %% [markdown]
# ### 1.3 Prueba del modelo en los datos de consumo de coches
#
# Ya podemos usar nuestra función `pesos` en el dataset real que hemos descargado. Para ver el ajuste, dibuja de nuevo los datos junto con la recta que has obtenido, en la misma gráfica. Tendrás que convertir los dataframes de Pandas en arrays de numpy para poder aplicar las operaciones matriciales.
#
# TIP: Revisa las dimensiones de todos los arrays para ver que son correctas.

# %% [markdown]
# $y = 46.31736 + -0.00768 x$

# %%
# TODO Aplica el modelo y dibuja la recta junto con los datos
import matplotlib.pyplot as plt

X_w = auto_mpg.data.features['weight'] 
X = auto_mpg.data.features
y = auto_mpg.data.targets
pesos = pesos_ols(X, y)
intercept = pesos[0]
coef_weight = pesos[1]

def visualiza(df, y):
    # TODO dibuja la gráfica
    plt.scatter(df, y)
    plt.xlabel('weight')
    plt.ylabel('MPG')
    x_line = np.linspace(X['weight'].min(), X['weight'].max(), 100)
    y_line = intercept + coef_weight * x_line
    plt.plot(x_line, y_line, color='red', label='Ajuste Lineal')
    plt.title('Ajuste Lineal de MPG en función de Weight')

    
visualiza(X_w, y)
# Out:
# (398, 1)
# (398, 1)
# (398, 2)
# (2, 398)

# %% [markdown]
# Por último, vamos a comprar el resultado con el que nos da `scikit-learn`para ver si nuestra implementación tiene buena pinta. Podemos ver cómo funciona en la [documentación](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html).

# %%
from sklearn.linear_model import LinearRegression

# Creamos el objeto
lr = LinearRegression()

# Le pasamos los datos en el formato correcto
X = auto_mpg.data.features 
y = auto_mpg.data.targets 

X_lr = X[['weight']]
y_lr = y

# Entrenamos con los datos
lr.fit(X_lr,y_lr)
print("Punto de corte:", lr.intercept_)
print("Pendiente:", lr.coef_)
# Out:
# Punto de corte: [46.31736442]
# Pendiente: [[-0.00767661]]

# %% [markdown]
# **TODO**: Analiza el resultado obtenido y compáralo con el de sklearn

# %% [markdown]
# ### 1.4 Compara el método de mínimos cuadrados y el descenso del gradiente para obtener los coeficientes de una regresión lineal

# %%
X = auto_mpg.data.features
y = auto_mpg.data.targets
X_w = auto_mpg.data.features['weight'] 

pesos = pesos_ols(X, y)
intercept = pesos[0]
coef_weight = pesos[1]
print(coef_weight)

pesos = pesos.reshape(2,1)
pesos
# Out:
# (398, 1)
# (398, 1)
# (398, 2)
# (2, 398)
# [-0.00767661]
# array([[ 4.63173644e+01],
#        [-7.67661006e-03]])

# %%
w0 = pesos
w0
# Out:
# array([[ 4.63173644e+01],
#        [-7.67661006e-03]])

# %%
eta = 0.01

# %%
n_iter = 500

# %%
w = [w0]
rss = [np.inf]
w_iter = w0
w_iter2 = w_iter.T
w_iter2.shape
# Out:
# (1, 2)

# %%
ones = np.ones((X.shape[0], 1))
X_weight = X['weight'].values.reshape(-1, 1)  # Convertir a array bidimensional
X_weight_b = np.concatenate((ones, X_weight), axis=1)

# %%
X_weight_b
X_weight_b.shape
# Out:
# (398, 2)

# %%
for i in range(n_iter):
    print("Iteración: " + str(i))
    y_hat = np.dot(X_weight_b, w_iter)
    error = (y_hat - y)
    rss_iter = (1/2)*np.dot(error.T, error) # 1/2 * (y_hat - y)^2
    grad_rss = np.dot(X_ones.T, error) 
    print(w_iter.shape)
    w_iter = w_iter - eta*grad_rss # suma vectorial
    w.append(w_iter)
    rss.append(rss_iter)
    print(w_iter)
    print(rss_iter)
# Out:
# Iteración: 0
# (2, 1)
# [[ 4.63173644e+01]
#  [-7.67661006e-03]]
# [[3737.40700719]]
# Iteración: 1
# (2, 1)
# [[ 4.63173644e+01]
#  [-7.67661033e-03]]
# [[3737.40700719]]
# Iteración: 2
# (2, 1)
# [[ 4.63173676e+01]
#  [-7.67343589e-03]]
# [[3737.40700719]]
# Iteración: 3
# (2, 1)
# [[ 4.62798290e+01]
#  [-4.52120466e-02]]
# [[3737.4261443]]
# Iteración: 4
# (2, 1)
# [[490.18403566]
#  [443.85899463]]
# [[2679813.48636011]]
# Iteración: 5
# (2, 1)
# [[-5248796.91402319]
#  [-5248843.23906422]]
# [[3.74214479e+14]]
# Iteración: 6
# (2, 1)
# [[6.20689884e+10]
#  [6.20689884e+10]]
# [[5.23290341e+22]]
# Iteración: 7
# (2, 1)
# [[-7.33982546e+14]
#  [-7.33982546e+14]]
# [[7.31753569e+30]]
# Iteración: 8
# (2, 1)
# [[8.67954179e+18]
#  [8.67954179e+18]]
# [[1.02326232e+39]]
# Iteración: 9
# (2, 1)
# [[-1.02637925e+23]
#  [-1.02637925e+23]]
# [[1.43089943e+47]]
# Iteración: 10
# (2, 1)
# [[1.21372118e+27]
#  [1.21372118e+27]]
# [[2.00092699e+55]]
# Iteración: 11
# (2, 1)
# [[-1.43525806e+31]
#  [-1.43525806e+31]]
# [[2.79803649e+63]]
# Iteración: 12
# (2, 1)
# [[1.69723141e+35]
#  [1.69723141e+35]]
# [[3.91269058e+71]]
# Iteración: 13
# (2, 1)
# [[-2.00702197e+39]
#  [-2.00702197e+39]]
# [[5.47138954e+79]]
# Iteración: 14
# (2, 1)
# [[2.37335767e+43]
#  [2.37335767e+43]]
# [[7.65102757e+87]]
# Iteración: 15
# (2, 1)
# [[-2.80655952e+47]
#  [-2.80655952e+47]]
# [[1.06989682e+96]]
# Iteración: 16
# (2, 1)
# [[3.31883241e+51]
#  [3.31883241e+51]]
# [[1.49611173e+104]]
# Iteración: 17
# (2, 1)
# [[-3.92460893e+55]
#  [-3.92460893e+55]]
# [[2.09211792e+112]]
# Iteración: 18
# (2, 1)
# [[4.64095603e+59]
#  [4.64095603e+59]]
# [[2.92555516e+120]]
# Iteración: 19
# (2, 1)
# [[-5.48805581e+63]
#  [-5.48805581e+63]]
# [[4.09100888e+128]]
# Iteración: 20
# (2, 1)
# [[6.48977417e+67]
#  [6.48977417e+67]]
# [[5.72074452e+136]]
# Iteración: 21
# (2, 1)
# [[-7.67433318e+71]
#  [-7.67433318e+71]]
# [[7.99971812e+144]]
# Iteración: 22
# (2, 1)
# [[9.0751062e+75]
#  [9.0751062e+75]]
# [[1.11865667e+153]]
# Iteración: 23
# (2, 1)
# [[-1.07315581e+80]
#  [-1.07315581e+80]]
# [[1.56429604e+161]]
# Iteración: 24
# (2, 1)
# [[1.26903572e+84]
#  [1.26903572e+84]]
# [[2.18746482e+169]]
# Iteración: 25
# (2, 1)
# [[-1.500669e+88]
#  [-1.500669e+88]]
# [[3.05888541e+177]]
# Iteración: 26
# (2, 1)
# [[1.77458162e+92]
#  [1.77458162e+92]]
# [[4.27745392e+185]]
# Iteración: 27
# (2, 1)
# [[-2.09849067e+96]
#  [-2.09849067e+96]]
# [[5.98146369e+193]]
# Iteración: 28
# (2, 1)
# [[2.48152188e+100]
#  [2.48152188e+100]]
# [[8.36430001e+201]]
# Iteración: 29
# (2, 1)
# [[-2.93446663e+104]
#  [-2.93446663e+104]]
# [[1.16963871e+210]]
# Iteración: 30
# (2, 1)
# [[3.47008602e+108]
#  [3.47008602e+108]]
# [[1.63558781e+218]]
# Iteración: 31
# (2, 1)
# [[-4.10347041e+112]
#  [-4.10347041e+112]]
# [[2.28715709e+226]]
# Iteración: 32
# (2, 1)
# [[4.85246455e+116]
#  [4.85246455e+116]]
# [[3.1982921e+234]]
# Iteración: 33
# (2, 1)
# [[-5.73817035e+120]
#  [-5.73817035e+120]]
# [[4.47239607e+242]]
# Iteración: 34
# (2, 1)
# [[6.78554136e+124]
#  [6.78554136e+124]]
# [[6.25406496e+250]]
# Iteración: 35
# (2, 1)
# [[-8.02408587e+128]
#  [-8.02408587e+128]]
# [[8.74549748e+258]]
# Iteración: 36
# (2, 1)
# [[9.48869819e+132]
#  [9.48869819e+132]]
# [[1.22294422e+267]]
# Iteración: 37
# (2, 1)
# [[-1.12206418e+137]
#  [-1.12206418e+137]]
# [[1.71012864e+275]]
# Iteración: 38
# (2, 1)
# [[1.32687119e+141]
#  [1.32687119e+141]]
# [[2.39139277e+283]]
# Iteración: 39
# (2, 1)
# [[-1.56906101e+145]
#  [-1.56906101e+145]]
# [[3.34405216e+291]]
# Iteración: 40
# (2, 1)
# [[1.85545701e+149]
#  [1.85545701e+149]]
# [[4.67622258e+299]]
# Iteración: 41
# (2, 1)
# [[-2.19412801e+153]
#  [-2.19412801e+153]]
# [[6.53908986e+307]]
# Iteración: 42
# (2, 1)
# [[2.59461561e+157]
#  [2.59461561e+157]]
# [[inf]]
# Iteración: 43
# (2, 1)
# [[-3.06820301e+161]
#  [-3.06820301e+161]]
# [[inf]]
# Iteración: 44
# (2, 1)
# [[3.6282329e+165]
#  [3.6282329e+165]]
# [[inf]]
# Iteración: 45
# (2, 1)
# [[-4.29048337e+169]
#  [-4.29048337e+169]]
# [[inf]]
# Iteración: 46
# (2, 1)
# [[5.07361243e+173]
#  [5.07361243e+173]]
# [[inf]]
# Iteración: 47
# (2, 1)
# [[-5.99968369e+177]
#  [-5.99968369e+177]]
# [[inf]]
# Iteración: 48
# (2, 1)
# [[7.09478795e+181]
#  [7.09478795e+181]]
# [[inf]]
# Iteración: 49
# (2, 1)
# [[-8.38977831e+185]
#  [-8.38977831e+185]]
# [[inf]]
# Iteración: 50
# (2, 1)
# [[9.92113938e+189]
#  [9.92113938e+189]]
# [[inf]]
# Iteración: 51
# (2, 1)
# [[-1.17320152e+194]
#  [-1.17320152e+194]]
# [[inf]]
# Iteración: 52
# (2, 1)
# [[1.38734247e+198]
#  [1.38734247e+198]]
# [[inf]]
# Iteración: 53
# (2, 1)
# [[-1.64056993e+202]
#  [-1.64056993e+202]]
# [[inf]]
# Iteración: 54
# (2, 1)
# [[1.94001824e+206]
#  [1.94001824e+206]]
# [[inf]]
# Iteración: 55
# (2, 1)
# [[-2.29412395e+210]
#  [-2.29412395e+210]]
# [[inf]]
# Iteración: 56
# (2, 1)
# [[2.71286351e+214]
#  [2.71286351e+214]]
# [[inf]]
# Iteración: 57
# (2, 1)
# [[-3.20803435e+218]
#  [-3.20803435e+218]]
# [[inf]]
# Iteración: 58
# (2, 1)
# [[3.79358723e+222]
#  [3.79358723e+222]]
# [[inf]]
# Iteración: 59
# (2, 1)
# [[-4.48601933e+226]
#  [-4.48601933e+226]]
# [[inf]]
# Iteración: 60
# (2, 1)
# [[5.30483898e+230]
#  [5.30483898e+230]]
# [[inf]]
# Iteración: 61
# (2, 1)
# [[-6.27311533e+234]
#  [-6.27311533e+234]]
# [[inf]]
# Iteración: 62
# (2, 1)
# [[7.41812825e+238]
#  [7.41812825e+238]]
# [[inf]]
# Iteración: 63
# (2, 1)
# [[-8.77213694e+242]
#  [-8.77213694e+242]]
# [[inf]]
# Iteración: 64
# (2, 1)
# [[1.03732888e+247]
#  [1.03732888e+247]]
# [[inf]]
# Iteración: 65
# (2, 1)
# [[-1.22666941e+251]
#  [-1.22666941e+251]]
# [[inf]]
# Iteración: 66
# (2, 1)
# [[1.45056969e+255]
#  [1.45056969e+255]]
# [[inf]]
# Iteración: 67
# (2, 1)
# [[-1.71533783e+259]
#  [-1.71533783e+259]]
# [[inf]]
# Iteración: 68
# (2, 1)
# [[2.02843329e+263]
#  [2.02843329e+263]]
# [[inf]]
# Iteración: 69
# (2, 1)
# [[-2.39867714e+267]
#  [-2.39867714e+267]]
# [[inf]]
# Iteración: 70
# (2, 1)
# [[2.83650048e+271]
#  [2.83650048e+271]]
# [[inf]]
# Iteración: 71
# (2, 1)
# [[-3.3542384e+275]
#  [-3.3542384e+275]]
# [[inf]]
# Iteración: 72
# (2, 1)
# [[3.96647748e+279]
#  [3.96647748e+279]]
# [[inf]]
# Iteración: 73
# (2, 1)
# [[-4.69046671e+283]
#  [-4.69046671e+283]]
# [[inf]]
# Iteración: 74
# (2, 1)
# [[5.54660353e+287]
#  [5.54660353e+287]]
# [[inf]]
# Iteración: 75
# (2, 1)
# [[-6.55900843e+291]
#  [-6.55900843e+291]]
# [[inf]]
# Iteración: 76
# (2, 1)
# [[7.75620456e+295]
#  [7.75620456e+295]]
# [[inf]]
# Iteración: 77
# (2, 1)
# [[-9.17192131e+299]
#  [-9.17192131e+299]]
# [[inf]]
# Iteración: 78
# (2, 1)
# [[1.08460446e+304]
#  [1.08460446e+304]]
# [[inf]]
# Iteración: 79
# (2, 1)
# [[-inf]
#  [-inf]]
# [[inf]]
# Iteración: 80
# (2, 1)
# [[nan]
#  [nan]]
# [[inf]]
# Iteración: 81
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 82
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 83
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 84
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 85
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 86
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 87
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 88
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 89
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 90
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 91
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 92
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 93
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 94
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 95
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 96
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 97
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 98
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 99
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 100
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 101
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 102
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 103
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 104
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 105
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 106
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 107
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 108
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 109
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 110
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 111
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 112
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 113
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 114
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 115
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 116
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 117
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 118
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 119
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 120
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 121
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 122
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 123
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 124
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 125
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 126
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 127
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 128
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 129
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 130
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 131
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 132
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 133
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 134
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 135
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 136
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 137
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 138
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 139
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 140
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 141
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 142
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 143
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 144
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 145
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 146
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 147
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 148
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 149
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 150
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 151
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 152
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 153
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 154
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 155
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 156
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 157
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 158
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 159
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 160
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 161
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 162
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 163
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 164
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 165
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 166
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 167
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 168
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 169
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 170
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 171
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 172
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 173
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 174
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 175
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 176
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 177
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 178
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 179
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 180
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 181
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 182
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 183
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 184
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 185
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 186
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 187
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 188
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 189
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 190
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 191
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 192
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 193
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 194
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 195
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 196
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 197
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 198
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 199
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 200
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 201
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 202
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 203
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 204
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 205
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 206
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 207
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 208
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 209
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 210
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 211
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 212
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 213
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 214
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 215
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 216
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 217
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 218
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 219
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 220
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 221
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 222
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 223
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 224
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 225
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 226
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 227
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 228
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 229
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 230
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 231
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 232
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 233
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 234
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 235
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 236
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 237
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 238
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 239
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 240
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 241
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 242
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 243
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 244
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 245
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 246
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 247
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 248
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 249
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 250
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 251
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 252
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 253
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 254
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 255
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 256
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 257
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 258
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 259
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 260
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 261
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 262
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 263
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 264
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 265
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 266
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 267
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 268
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 269
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 270
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 271
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 272
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 273
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 274
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 275
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 276
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 277
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 278
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 279
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 280
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 281
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 282
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 283
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 284
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 285
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 286
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 287
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 288
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 289
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 290
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 291
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 292
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 293
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 294
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 295
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 296
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 297
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 298
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 299
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 300
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 301
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 302
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 303
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 304
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 305
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 306
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 307
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 308
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 309
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 310
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 311
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 312
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 313
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 314
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 315
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 316
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 317
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 318
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 319
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 320
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 321
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 322
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 323
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 324
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 325
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 326
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 327
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 328
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 329
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 330
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 331
# C:\Users\papui\AppData\Local\Temp\ipykernel_9948\269351435.py:8: RuntimeWarning: invalid value encountered in subtract
#   w_iter = w_iter - eta*grad_rss # suma vectorial
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 332
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 333
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 334
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 335
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 336
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 337
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 338
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 339
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 340
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 341
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 342
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 343
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 344
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 345
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 346
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 347
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 348
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 349
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 350
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 351
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 352
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 353
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 354
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 355
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 356
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 357
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 358
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 359
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 360
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 361
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 362
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 363
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 364
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 365
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 366
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 367
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 368
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 369
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 370
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 371
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 372
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 373
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 374
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 375
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 376
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 377
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 378
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 379
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 380
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 381
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 382
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 383
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 384
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 385
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 386
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 387
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 388
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 389
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 390
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 391
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 392
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 393
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 394
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 395
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 396
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 397
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 398
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 399
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 400
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 401
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 402
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 403
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 404
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 405
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 406
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 407
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 408
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 409
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 410
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 411
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 412
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 413
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 414
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 415
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 416
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 417
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 418
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 419
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 420
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 421
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 422
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 423
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 424
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 425
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 426
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 427
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 428
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 429
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 430
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 431
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 432
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 433
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 434
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 435
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 436
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 437
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 438
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 439
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 440
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 441
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 442
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 443
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 444
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 445
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 446
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 447
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 448
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 449
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 450
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 451
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 452
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 453
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 454
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 455
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 456
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 457
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 458
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 459
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 460
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 461
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 462
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 463
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 464
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 465
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 466
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 467
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 468
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 469
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 470
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 471
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 472
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 473
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 474
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 475
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 476
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 477
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 478
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 479
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 480
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 481
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 482
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 483
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 484
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 485
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 486
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 487
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 488
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 489
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 490
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 491
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 492
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 493
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 494
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 495
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 496
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 497
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 498
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]
# Iteración: 499
# (2, 1)
# [[nan]
#  [nan]]
# [[nan]]

# %%
w_iter
# Out:
# array([[nan],
#        [nan]])

# %%
w[1]
# Out:
# array([[ 4.63173644e+01],
#        [-7.67661006e-03]])

# %%
pesos = pesos.reshape(2,1)
pesos
print(f'El método del MCO:\n {pesos}\n\n y del descenso del gradiente:\n {w[1]}\n\n  dan el mismo resultado')
# Out:
# El método del MCO:
#  [[ 4.63173644e+01]
#  [-7.67661006e-03]]
#
#  y del descenso del gradiente:
#  [[ 4.63173644e+01]
#  [-7.67661006e-03]]
#
#   dan el mismo resultado

# %% [markdown]
# ## 2. Optimización con descenso del gradiente [OPCIONAL]
#
# Este ejercicio es opcional, no es necesario hacerlo para conseguir el APTO en la práctica, pero podéis hacerlo si queréis practicar más sobre el método del descenso del gradiente, que es muy importante en machine learning.
#
# Vamos a resolver el mismo problema usando el descenso del gradiente en lugar de la solución analítica. El descenso del gradiente es un método de optimización iterativo que usa el operador gradiente.
#
# Como es iterativo, necesitamos decirle cuándo tiene que parar y darnos la solución. En este caso, le vamos a decir que pare y nos devuelva la solución después de un número de iteraciones que le pasaremos como parámetro. La ecuación iterativa es.
#
# $$w^{t+1} = w^t - \eta \cdot \nabla f(w)$$
#
# donde f es nuestra función objetivo, y w es un vector. Para la función objetivo, vamos a usar el error RSS, que querremos minimizar.
#
# $$ RSS(w) = \frac{1}{2}\sum_{n=1}^{N}[y_n-f(x_n)]^2$$
#
# y cuyo gradiente es:
#
# $$\nabla RSS(w) = X^T(Xw^t-y)$$
#
# TIP: Ten en cuenta que el RSS también lo puedes escribir como $\frac{1}{2}\sum_{n=1}^{N}[y_n-\hat{y_n}]^2$ donde $\hat{y_n} = X \hat{w}$ en cada paso.

# %% [markdown]
# ### 2.1 Implementar el descenso del gradiente
#
# Completa las siguientes funciones para implementar el descenso del gradiente con la función objetivo de la regresión lineal. La función necesitará:
#
# - La entrada X y salida y de la regresión
# - Un punto inicial desde el que empezar a iterar
# - El número de iteraciones
# - El learning rate
#
# La función nos devolverá un array con las w resultantes de las iteraciones y otro con el valor de la función en cada paso del algoritmo, a la que también se conoce como *loss function*.

# %%
import numpy as np

def gradient_descent(X, y, w0, n_iter, eta): 
    # Define la función que calcule n_iter iteraciones del descenso del gradiente
    
    # Inicializamos variables
    # Si eliges otra forma de resolverlo, puedes borrar esta parte
    loss_iter = [np.inf]
    w_iter = [w0]
    w = w0
    
    # TODO 1 Añade la columna de 1s
    
    
    # TODO 2 Haz un bucle para las iteraciones 
    # TODO 3 Dentro del bucle tendrás que actualizar el error y los pesos y añadirlos a las listas
    
    
    # Devuelve los resultados
    return np.array(w_iter), np.array(loss_iter)

eta = 0.01 
iteraciones = 2000 

np.random.seed(123)
w0 = np.random.rand(2).reshape((2,1))

y = np.array([208500, 181500, 223500, 140000, 250000]).reshape((5,1))
X = np.array( [[  0.37020659],
               [  -0.48234664],
               [  0.51483616],
               [  0.38352774],
               [  1.29888065]])

weights, loss = gradient_descent(X, y, w0, iteraciones, eta)

print(weights[-1])
# Out:
# [[0.69646919]
#  [0.28613933]]

# %% [markdown]
# ### 2.2 Aplicar al dataset de consumo de combustible
#
# Leemos de nuevo los datos y aplicamos la función que acabamos de programar.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
auto_mpg = fetch_ucirepo(id=9) 
  
# data (as pandas dataframes) 
X = auto_mpg.data.features 
y = auto_mpg.data.targets 
  
# convert to numpy
X_np = X['weight'].to_numpy().reshape((X.shape[0], 1))
y_np = y.to_numpy()

print(X_np.shape)
print(y_np.shape)
# Out:
# (398, 1)
# (398, 1)

# %%
def visualiza(df, y):
    # TODO dibuja la gráfica
    plt.scatter(df, y)
    plt.xlabel('weight')
    plt.ylabel('MPG')
    x_line = np.linspace(X['weight'].min(), X['weight'].max(), 100)
    y_line = intercept + coef_weight * x_line
    plt.plot(x_line, y_line, color='red', label='Ajuste Lineal')
    plt.title('Ajuste Lineal de MPG en función de Weight')

# %% [markdown]
# Para ayudar al algoritmo, vamos a escalar la variable X, restando la media y dividiendo entre la desviación estándar. Después aplicamos la función anterior y dibujamos.

# %%
# TODO Aplica el modelo y dibuja la recta junto con los datos

X = auto_mpg.data.features
y = auto_mpg.data.targets

# Escalamos la variable x 
X_np = X['weight'].to_numpy().reshape((X.shape[0], 1))
y_np = y.to_numpy()

X_gd=(X_np - X_np.mean()) / X_np.std()
y_gd = y_np

# TODO 1 Punto inicial y learning rate
w0 = [pesos]
eta = 0.01

# TODO 2 Aplicamos el algoritmo
w = [w0]
rss = [np.inf]
w_iter = w0

ones = np.ones((X.shape[0], 1))
X_weight = X['weight'].values.reshape(-1, 1)  # Convertir a array bidimensional
X_weight_b = np.concatenate((ones, X_weight), axis=1)


for i in range(n_iter):
    print("Iteración: " + str(i))
    y_hat = np.dot(X_weight_b, w_iter)
    error = (y_hat - y)
    rss_iter = (1/2)*np.dot(error.T, error) # 1/2 * (y_hat - y)^2
    grad_rss = np.dot(X_ones.T, error) 
    print(w_iter.shape)
    w_iter = w_iter - eta*grad_rss # suma vectorial
    w.append(w_iter)
    rss.append(rss_iter)
    print(w_iter)
    print(rss_iter)
    
# Límites de los ejes
x_max = np.max(X_gd) + 1
x_min = np.min(X_gd) -1


# TODO 3 Dibuja la gráfica
visualiza(x_max, x_min)
# Out:
# Iteración: 0
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\papui\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\papui\AppData\Local\Temp\ipykernel_9948\3674667886.py", line 31, in <module>
#     error = (y_hat - y)
#              ~~~~~~^~~
#   File "C:\Users\papui\anaconda3\Lib\site-packages\pandas\core\generic.py", line 2102, in __array_ufunc__
#     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\site-packages\pandas\core\arraylike.py", line 273, in array_ufunc
#     result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "ops_dispatch.pyx", line 113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op
#   File "C:\Users\papui\anaconda3\Lib\site-packages\pandas\core\ops\common.py", line 76, in new_method
#     return method(self, other)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\site-packages\pandas\core\arraylike.py", line 198, in __rsub__
#     return self._arith_method(other, roperator.rsub)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\site-packages\pandas\core\frame.py", line 7641, in _arith_method
#     self, other = self._align_for_op(other, axis, flex=True, level=None)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\site-packages\pandas\core\frame.py", line 7906, in _align_for_op
#     raise ValueError(
# ValueError: Unable to coerce to Series/DataFrame, dimension must be <= 2: (398, 1, 1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\papui\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 1155, in get_records
#     FrameInfo(
#   File "C:\Users\papui\anaconda3\Lib\site-packages\IPython\core\ultratb.py", line 780, in __init__
#     ix = inspect.getsourcelines(frame)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\inspect.py", line 1244, in getsourcelines
#     lines, lnum = findsource(object)
#                   ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\papui\anaconda3\Lib\inspect.py", line 1081, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code
